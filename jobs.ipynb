# %%
import os
from supabase import create_client, Client
import streamlit as st
import pandas as pd

# Function to handle Supabase initialization and authentication
def init_supabase():
  try:
    # Fetch environment variables
    url = 'https://tvmobnxbcngtdyfuqgue.supabase.co'
    key = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InR2bW9ibnhiY25ndGR5ZnVxZ3VlIiwicm9sZSI6ImFub24iLCJpYXQiOjE3MDI3MzgyODUsImV4cCI6MjAxODMxNDI4NX0.3lo6cEPrmPwK8WfXzsC0Nz_U1jxZz5r67cucR-8808k'
    
    # Create Supabase client
    client = create_client(url, key)
    
    # Sign in with dedicated user credentials
    email = 'bbetancova@gmail.com'
    password = '5vXZ4ZpWEDiE'
    
    session = client.auth.sign_in_with_password({"email": "bbetancova@gmail.com", "password": "5vXZ4ZpWEDiE"})
    print(session)
    
    # if session.error:
    #   raise Exception(f"Sign-in failed: {session.error}")
      
    # Extract access token
    # access_token = session.data.token
    
    return client
  except Exception as e:
    print(f"Error initializing Supabase: {e}")
    # st.error(f"Current email and pass are:{email} and {password}.")
    # st.error(f"current SUPABASE SITE and key are {url} and {key}")
    raise SystemExit(1)


# Initialize Supabase and get access token
supabase = init_supabase()

# Define table name
table_name = "jobs"  # or "moar-jobs" if that's the actual name

# Try fetching data and creating DataFrame
try:
  # Set headers with access token
  # headers = {"Authorization": f"Bearer {access_token}"}
  
  # Fetch data from Supabase
  response = supabase.table(table_name).select("*").execute()
  
  # Check for response errors
  # if response.error:
  #   raise Exception(f"Data retrieval error: {response.error}")
  
  # Get data and create DataFrame
  data = response.data
  df = pd.DataFrame(data)
  
  # Success message
  print(f"Fetched {len(df)} jobs from {table_name} table.")
  
  # Use the DataFrame for further analysis or visualization in your Streamlit app
  df

except Exception as e:
  print.error(f"Error fetching and processing data: {e}")

# Handle any other top-level exceptions
except Exception as e:
  print.exception(e)
# Out:
# 2023-12-16 21:54:42,942:INFO - HTTP Request: POST https://tvmobnxbcngtdyfuqgue.supabase.co/auth/v1/token?grant_type=password "HTTP/1.1 200 OK"
# 2023-12-16 21:54:43,109:INFO - HTTP Request: GET https://tvmobnxbcngtdyfuqgue.supabase.co/rest/v1/jobs?select=%2A "HTTP/1.1 200 OK"
# ...

# %%
df
# Out:
#                                                 title    company  \
# 0   Strategy Lead, Product Operations, Chrome Browser     Google
# 1                    Senior UX Design Manager, Search     Google
# 2     Principal Engineer, Foundations API and Runtime     Google
# 3                         Principal Software Engineer  Snowflake
# 4                                  Principal Engineer   fanatics
# ..                                                ...        ...
# 93                         Senior Manager Engineering  Snowflake
# 94              Principal Software Engineer - Backend    Momence
# 95                Senior Software Engineering Manager     Google
# 96                           Senior Staff AI Engineer  Amplitude
# 97                       Software Engineer, Front-End  Grammarly
#
#                        location  min_pay  median_pay  max_pay  \
# 0   San Francisco/Mountain View   203000      251000   299000
# ...
